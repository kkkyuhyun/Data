# %% [markdown]
# ## 데이터 준비

# %%
# 관련 라이브러리 불러오기
import pandas as pd           #판다스
import matplotlib as mpl
import seaborn as sns
#타이타닉 데이터 파일경로를 찾고 변수 file_path에 저장
xxx = './titanic.csv'
print(xxx)

df = pd.read_csv(xxx) #read csv()함수로 데이터프레임 변환 
df
# Out:
# ./titanic.csv
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic_copy_backup = df.copy()
titanic_copy_backup
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#to_csv 메소드를 사용하여 내장 데이터프레임을 csv파일로 저장
# C:\data폴더에 저장 
df.to_csv('./titanic_csv_backup.csv')
#original 보존 backup 파일

# %%
file_path= './titanic_csv_backup.csv'
titanic_csv_backup = pd.read_csv(file_path)
titanic_csv_backup
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %% [markdown]
# ## 데이터 보기

# %%
df.info() #데이터프레임의 기본 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe() #데이터프레임의 기초 통계 확인
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes # 데이터유형 확인 
#시험 문제!
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.loc[0] # 데이터 행 인덱스 확인
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
df.head() # 상위 데이터 추출
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail() # 하위 데이터 추출
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.index # 데이터프레임 인덱스 보기
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.values # 행, 열 구조 보기
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import missingno as msno #라이브러리 정리

# %%
df.sort_values(by=['Fare'], axis=0) # 요금 기준 오름차순 정렬
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 271    male  25.0      0      0      LINE    0.0000          NaN        S
# 597    male  49.0      0      0      LINE    0.0000          NaN        S
# 302    male  19.0      0      0      LINE    0.0000          NaN        S
# 633    male   NaN      0      0    112052    0.0000          NaN        S
# 277    male   NaN      0      0    239853    0.0000          NaN        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 341  female  24.0      3      2     19950  263.0000  C23 C25 C27        S
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
#
# [891 rows x 12 columns]

# %%
df.sort_values(by=['Fare'], axis=0, ascending=False) # 요금 기준 내림차순 정렬
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 633    male   NaN      0      0    112052    0.0000          NaN        S
# 413    male   NaN      0      0    239853    0.0000          NaN        S
# 822    male  38.0      0      0     19972    0.0000          NaN        S
# 732    male   NaN      0      0    239855    0.0000          NaN        S
# 674    male   NaN      0      0    239856    0.0000          NaN        S
#
# [891 rows x 12 columns]

# %%
df.sort_index(axis=1) #열 이름을 (알파벳 순서로) 정렬하기 : axis=1 Age부터 출력
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888   NaN   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas      0          887
# 887                       Graham, Miss. Margaret Edith      0          888
# 888           Johnston, Miss. Catherine Helen "Carrie"      2          889
# 889                              Behr, Mr. Karl Howell      0          890
# 890                                Dooley, Mr. Patrick      0          891
#
#      Pclass     Sex  SibSp  Survived            Ticket
# 0         3    male      1         0         A/5 21171
# 1         1  female      1         1          PC 17599
# 2         3  female      0         1  STON/O2. 3101282
# 3         1  female      1         1            113803
# 4         3    male      0         0            373450
# ..      ...     ...    ...       ...               ...
# 886       2    male      0         0            211536
# 887       1  female      0         1            112053
# 888       3  female      1         0        W./C. 6607
# 889       1    male      0         1            111369
# 890       3    male      0         0            370376
#
# [891 rows x 12 columns]

# %% [markdown]
# ## 데이터클린징

# %%
df.count() # 데이터 갯수 확인
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df.isnull().sum() # 결측치 확인
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 결측치 시각화

# %%
sns.heatmap(df.isnull(),cbar=False) # 시본 시각화 확인
# Out:
# <Axes: >

# %%
sns.heatmap(df.isnull(),cbar=True) # 시본 시각화 확인
# Out:
# <Axes: >

# %%
import missingno as msno # missingno 패키지 임포트
#msno.matrix(df) # 매트릭스 결측치 시각화

# %%
msno.bar(df) # 바챠트 결측치 시각화
# Out:
# <Axes: >

# %%
msno.heatmap(df) # 히트맵 결측치 시각화
# Out:
# <Axes: >

# %%
msno.dendrogram(df) # 덴드로그램 결측치 시각화
# Out:
# <Axes: >

# %% [markdown]
# #### Cabin 결측 제거

# %%
df['Cabin'].value_counts() #Cabin 삭제전 결측치 내용 확인
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
df = df.dropna(thresh=int(len(df) * 0.5), axis=1) #결측치 제거
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
msno.matrix(df) #결측치 제거 확인
# Out:
# <Axes: >

# %% [markdown]
# ### Embarked(탑승) 대체

# %%
df['Embarked'].value_counts()    # 범주형 개수 확인
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'] = df['Embarked'].fillna('S') # 최다빈도 ‘S’로 대체
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### 나이 대체

# %%
df['Age']=df['Age'].fillna(df['Age'].mean()) # 나이 평균값으로 대체
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
msno.matrix(df) #결측치 제거 최종 확인
# Out:
# <Axes: >

# %% [markdown]
# ## 데이터탐색

# %%
# 데이터 바이닝 - 연속형 나이 변수 범주화 cut() 함수 사용 
bins = [1, 20, 60, 100] # 1-20 미성년, 21-60 : 성년, 61-100 : 성년
df_Age = pd.cut(df["Age"], bins, labels =["미성년", "성년", "노년"])
df["Age_class"] = df_Age
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked Age_class
# 0        0         A/5 21171   7.2500        S        성년
# 1        0          PC 17599  71.2833        C        성년
# 2        0  STON/O2. 3101282   7.9250        S        성년
# 3        0            113803  53.1000        S        성년
# 4        0            373450   8.0500        S        성년
# ..     ...               ...      ...      ...       ...
# 886      0            211536  13.0000        S        성년
# 887      0            112053  30.0000        S       미성년
# 888      2        W./C. 6607  23.4500        S       NaN
# 889      0            111369  30.0000        C        성년
# 890      0            370376   7.7500        Q        성년
#
# [891 rows x 12 columns]

# %%
t1 = df.Age_class.unique() # 범주형 중복없이 value 추출
t1
# Out:
# [성년, 미성년, 노년, NaN]
# Categories (3, object): [미성년 < 성년 < 노년]

# %%
t2 = df[df.Age_class.isin(['미성년'])] # 원하는 데이터만 
t2
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 12            13         0       3        Saundercock, Mr. William Henry
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# ..           ...       ...     ...                                   ...
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 876          877         0       3         Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch     Ticket     Fare Embarked Age_class
# 7      male   2.0      3      1     349909  21.0750        S       미성년
# 9    female  14.0      1      0     237736  30.0708        C       미성년
# 10   female   4.0      1      1    PP 9549  16.7000        S       미성년
# 12     male  20.0      0      0  A/5. 2151   8.0500        S       미성년
# 14   female  14.0      0      0     350406   7.8542        S       미성년
# ..      ...   ...    ...    ...        ...      ...      ...       ...
# 869    male   4.0      1      1     347742  11.1333        S       미성년
# 875  female  15.0      0      0       2667   7.2250        C       미성년
# 876    male  20.0      0      0       7534   9.8458        S       미성년
# 877    male  19.0      0      0     349212   7.8958        S       미성년
# 887  female  19.0      0      0     112053  30.0000        S       미성년
#
# [165 rows x 12 columns]

# %%
t3 = df[~df.Age_class.isin(['미성년'])] # 원하는 데이터 제외 필터링
t3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked Age_class
# 0        0         A/5 21171   7.2500        S        성년
# 1        0          PC 17599  71.2833        C        성년
# 2        0  STON/O2. 3101282   7.9250        S        성년
# 3        0            113803  53.1000        S        성년
# 4        0            373450   8.0500        S        성년
# ..     ...               ...      ...      ...       ...
# 885      5            382652  29.1250        Q        성년
# 886      0            211536  13.0000        S        성년
# 888      2        W./C. 6607  23.4500        S       NaN
# 889      0            111369  30.0000        C        성년
# 890      0            370376   7.7500        Q        성년
#
# [726 rows x 12 columns]

# %%
# 전체를 3개 범주로 구분
df_Age2 = pd.qcut(df["Age"], q=3, labels =["미성년", "성년", "노년"])
df["Age_class2"] = df_Age2
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Embarked Age_class Age_class2
# 0        1      0         A/5 21171   7.2500        S        성년        미성년
# 1        1      0          PC 17599  71.2833        C        성년         노년
# 2        0      0  STON/O2. 3101282   7.9250        S        성년         성년
# 3        1      0            113803  53.1000        S        성년         노년
# 4        0      0            373450   8.0500        S        성년         노년
# ..     ...    ...               ...      ...      ...       ...        ...
# 886      0      0            211536  13.0000        S        성년         성년
# 887      0      0            112053  30.0000        S       미성년        미성년
# 888      1      2        W./C. 6607  23.4500        S        성년         성년
# 889      0      0            111369  30.0000        C        성년         성년
# 890      0      0            370376   7.7500        Q        성년         노년
#
# [891 rows x 13 columns]

# %%
# 성별, 선실, 나이 그룹에 의한 생존율을 데이터프레임으로 계산한다. 
# 행에는 성별 및 나이 그룹에 대한 다중 인덱스를 사용하고 열에는 선실 인덱스를 사용한다.
df1 = df.groupby(['Sex','Age_class','Pclass'])["Survived"].mean()
df1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14272\1992388118.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df1 = df.groupby(['Sex','Age_class','Pclass'])["Survived"].mean()
# Sex     Age_class  Pclass
# female  미성년        1         0.928571
#                    2         1.000000
#                    3         0.465116
#         성년         1         0.971014
#                    2         0.896552
#                    3         0.407407
#         노년         1         1.000000
#                    2              NaN
#                    3         1.000000
# male    미성년        1         0.500000
#                    2         0.357143
#                    3         0.180556
#         성년         1         0.426829
#                    2         0.051948
#                    3         0.132948
#         노년         1         0.083333
#                    2         0.333333
#                    3         0.000000
# Name: Survived, dtype: float64

# %%
df2 = df1.unstack("Pclass")
df2
# Out:
# Pclass                   1         2         3
# Sex    Age_class
# female 미성년        0.928571  1.000000  0.465116
#        성년         0.971014  0.896552  0.407407
#        노년         1.000000       NaN  1.000000
# male   미성년        0.500000  0.357143  0.180556
#        성년         0.426829  0.051948  0.132948
#        노년         0.083333  0.333333  0.000000

# %%
# 피봇 테이블
# 성별 및 선실에 의한 생존율을 피봇 데이터 형태로 만든다
df.pivot_table(['Survived'],index=['Sex', 'Pclass'], aggfunc='mean')
# Out:
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %% [markdown]
# ## 데이터 탐색자동 보고서

# %%
import pandas_profiling
report = df.profile_report()
report.to_file('report.html')
#pandas_profiling/ydata_profiling 설치 안됨.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas_profiling
#       2 report = df.profile_report()
#       3 report.to_file('report.html')
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %% [markdown]
# ## 데이터 시각화 분석

# %% [markdown]
# ### 단일형 시각화

# %%
# 범주형 확인
# 남녀 성비 확인
import seaborn as sns
sns.catplot(x='Sex',kind='count',data=df)

# %%
# 좌석 등급별 성비 확인
sns.catplot(x='Pclass',kind='count',hue='Sex', data=df)

# %%
# 출발항구별 분포 확인
sns.catplot(x='Embarked', kind = 'count', data = df)

# %%
# 연속형 # 나이 분포 
df['Age'].hist()
# Out:
# <Axes: >

# %%
# 연속형 # 요금 분포 
df['Fare'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 범주형*범주형

# %%
# 생존자 분석
sns.catplot(x='Survived',kind='count',hue='Sex',data=df)

# %%
# 보기 편하게 생존자 구분 변환
df['Survivor'] = df['Survived'].map({0 : 'no', 1: 'yes'}) #mapping!
# 생존/성별
sns.catplot(x='Survivor', kind='count', hue='Sex', data=df)

# %%
# 성별/생존자
sns.catplot('Sex', kind='count', hue='Survivor', data=df)

# %% [markdown]
# ### 남자일수록 사망자가 많다.

# %%
# 좌석등급별 생존자 확인
sns.catplot(x='Pclass', kind='count', hue='Survivor', data=df)

# %%
#항구별/생존 
sns.catplot(x='Embarked', kind='count', hue='Survivor', data=df)

# %%
#연령대별/사망자 20세 미만의 아이들을 확인
sns.catplot(x='Age', kind='count', hue='Survivor', data=df.loc[df['Age'] < 20])

# %%
#연령대별/사망자 70세 이상 노인
sns.catplot(x='Age', kind='count', hue='Survivor', data=df.loc[df['Age'] >=70])

# %%
sns.lmplot(x='Age',y='Survived',hue='Sex',data=df.loc[df['Age']>=20]) #lmplot 회귀플롯

# %%
Pg = sns.PairGrid(df, y_vars="Survived",
                 x_vars=["Pclass", "Sex", "Embarked","Age_class"],
                 height=5, aspect=.7)
Pg.map(sns.pointplot, scale=1.3, errwidth=4, color="xkcd:plum")
Pg.set(ylim=(0, 1))
sns.despine(fig=Pg.fig, left=True)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   func(x=x, y=y, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 4}` instead.
#
#   func(x=x, y=y, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   func(x=x, y=y, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 4}` instead.
#
#   func(x=x, y=y, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).
#
#   func(x=x, y=y, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1615: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 4}` instead.
#
#   func(x=x, y=y, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 4
#       1 Pg = sns.PairGrid(df, y_vars="Survived",
#       2                  x_vars=["Pclass", "Sex", "Embarked","Age_class"],
#       3                  height=5, aspect=.7)
# ----> 4 Pg.map(sns.pointplot, scale=1.3, errwidth=4, color="xkcd:plum")
#       5 Pg.set(ylim=(0, 1))
#       6 sns.despine(fig=Pg.fig, left=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1379, in PairGrid.map(self, func, **kwargs)
#    1377 row_indices, col_indices = np.indices(self.axes.shape)
#    1378 indices = zip(row_indices.flat, col_indices.flat)
# -> 1379 self._map_bivariate(func, indices, **kwargs)
#    1381 return self
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1600, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1597 if self._hue_var is not None and self._hue_var not in axes_vars:
#    1598     axes_vars.append(self._hue_var)
# -> 1600 data = self.data[axes_vars]
#    1601 if self._dropna:
#    1602     data = data.dropna()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6251, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6248     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6251 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Age_class'] not in index"

# %%
# 한글처리
import matplotlib as plt
plt.rc('font', family='Malgun Gothic')

# %%
# Pairgrid bar서브플롯 적용 
Pg = sns.PairGrid(df, y_vars="Survived",
                 x_vars=["Pclass", "Sex", "Embarked","Age_class"],
                 height=5, aspect=.7)
Pg.map(sns.barplot)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 5
#       1 # Pairgrid bar서브플롯 적용
#       2 Pg = sns.PairGrid(df, y_vars="Survived",
#       3                  x_vars=["Pclass", "Sex", "Embarked","Age_class"],
#       4                  height=5, aspect=.7)
# ----> 5 Pg.map(sns.barplot)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1379, in PairGrid.map(self, func, **kwargs)
#    1377 row_indices, col_indices = np.indices(self.axes.shape)
#    1378 indices = zip(row_indices.flat, col_indices.flat)
# -> 1379 self._map_bivariate(func, indices, **kwargs)
#    1381 return self
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1574, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1572     if ax is None:  # i.e. we are in corner mode
#    1573         continue
# -> 1574     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1575 self._add_axis_labels()
#    1577 if "hue" in signature(func).parameters:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:1600, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1597 if self._hue_var is not None and self._hue_var not in axes_vars:
#    1598     axes_vars.append(self._hue_var)
# -> 1600 data = self.data[axes_vars]
#    1601 if self._dropna:
#    1602     data = data.dropna()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6199 self._raise_if_missing(keyarr, indexer, axis_name)
#    6201 keyarr = self.take(indexer)
#    6202 if isinstance(key, Index):
#    6203     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py:6251, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6248     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6251 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Age_class'] not in index"

# %%
# Pairgrid violin서브플롯 적용 
Pg.map(sns.violinplot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-5f862231db0d> in <module>
#       1 # Pairgrid violin서브플롯 적용
# ----> 2 Pg.map(sns.violinplot)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
#    1331
#    1332                     ax = self.axes[i, j]
# -> 1333                     plt.sca(ax)
#    1334
#    1335                     # Insert the other hue aesthetics if appropriate
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in sca(ax)
#     903             m.canvas.figure.sca(ax)
#     904             return
# --> 905     raise ValueError("Axes instance argument was not found in a figure")
#     906
#     907
#
# ValueError: Axes instance argument was not found in a figure

# %% [markdown]
# ### Pairgrid 범주형 전체 시각화(교재참조)

# %% [markdown]
# ### 범주형*연속형

# %%
#성별/나이
sns.distplot(df['Age'].loc[df['Sex']=='male'])

# %%
sns.distplot(df['Age'].loc[df['Sex']=='female'])

# %%
sns.catplot(x='Age', kind='count', hue='Survivor', data=df)

# %%
sns.lmplot(x='SibSp',y='Survived', hue='Sex',data=df)
# Out:
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\AppData\Roaming\Python\Python39\site-packages\seaborn\utils.py:61: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# c:\ProgramData\Miniconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# c:\ProgramData\Miniconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.lmplot(x='Parch',y='Survived', hue='Sex',data=df)

# %%
# 파생변수 만들기 
# 형제/자매와 부모/자식의 수를 더하여, 가족의 크기라는 특성을 만들어 본다.
df['family_Size'] = df['SibSp'] + df['Parch']
sns.lmplot('family_Size','Survived', hue='Sex', data=df)

# %%
sns.lmplot('Fare','Survived', hue='Sex',data=df)

# %% [markdown]
# ### 모둘생성과 파라미터

# %%
# 생존에 따른 bar차트 
def bar_chart(feature):
    Survived = df[df['Survived']==1][feature].value_counts()
    Dead = df[df['Survived']==0][feature].value_counts()
    df_titanic = pd.DataFrame([Survived,Dead])
    df_titanic.index = ['Survived','Dead']
    df_titanic.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
# 생존/성별
#여성이 남성보다 생존할 가능성이 더 높다는 것을 확인시켜 준다
bar_chart('Sex')

# %%
# 생존/등급별
#차트는 1등급 클래스가 다른 클래스보다 생존할 가능성이 더 높다는 것을 확인시켜 준다
#차트는 3등급 클래스가 다른 클래스보다 죽을 가능성이 더 높다는 것을 확인시켜 준다
bar_chart('Pclass')

# %%
bar_chart('Embarked')
